# %%
# ==============================
# STEP 0: INSTALL & IMPORTS
# ==============================

import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppress TensorFlow warnings

import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Conv1D, MaxPooling1D, Dense,
    Dropout, Flatten, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score

# %%
# ==============================
# STEP 1: LOAD DATA
# ==============================

FILE_PATH = "ABIDEII_Composite_Phenotypic.csv"

df = pd.read_csv(FILE_PATH, encoding='latin1', engine='python')
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (1114, 348)
#          SITE_ID  SUB_ID NDAR_GUID  DX_GROUP  PDD_DSM_IV_TR  ASD_DSM_5  \
# 0  ABIDEII-BNI_1   29006       NaN         1            NaN        NaN
# 1  ABIDEII-BNI_1   29007       NaN         1            NaN        NaN
# 2  ABIDEII-BNI_1   29008       NaN         1            NaN        NaN
# 3  ABIDEII-BNI_1   29009       NaN         1            NaN        NaN
# 4  ABIDEII-BNI_1   29010       NaN         1            NaN        NaN
#
#    AGE_AT_SCAN   SEX  HANDEDNESS_CATEGORY  HANDEDNESS_SCORES  ...  \
# 0          48.0    1                  1.0                NaN  ...
# 1          41.0    1                  1.0                NaN  ...
# 2          59.0    1                  1.0                NaN  ...
# 3          57.0    1                  1.0                NaN  ...
# 4          45.0    1                  1.0                NaN  ...
#
#    ADI_R_C3_TOTAL  ADI_R_C4_REPETITIVE_USE_OBJECTS  ADI_R_C4_HIGHER  \
# 0             NaN                              NaN              NaN
# 1             NaN                              NaN              NaN
# 2             NaN                              NaN              NaN
# 3             NaN                              NaN              NaN
# 4             NaN                              NaN              NaN
#
#   ADI_R_C4_UNUSUAL_SENSORY_INTERESTS ADI_R_C4_TOTAL  \
# 0                                NaN            NaN
# 1                                NaN            NaN
# 2                                NaN            NaN
# 3                                NaN            NaN
# 4                                NaN            NaN
#
#   ADI_R_D_AGE_PARENT_NOTICED  ADI_R_D_AGE_FIRST_SINGLE_WORDS  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    ADI_R_D_AGE_FIRST_PHRASES  ADI_R_D_AGE_WHEN_ABNORMALITY  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    ADI_R_D_INTERVIEWER_JUDGMENT
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 348 columns]

# %%
# ==============================
# STEP 2: TARGET & FEATURE SPLIT
# ==============================

TARGET = "DX_GROUP"   # 1 = ASD, 2 = Control

y = df[TARGET].map({1: 1, 2: 0})

drop_cols = ["DX_GROUP", "SUB_ID", "FILE_ID", "SITE_ID"]
X = df.drop(columns=[c for c in drop_cols if c in df.columns])

print("X shape:", X.shape)
print("y distribution:\n", y.value_counts())
# Out:
# X shape: (1114, 345)
# y distribution:
#  DX_GROUP
# 0    593
# 1    521
# Name: count, dtype: int64

# %%
# ==============================
# STEP 3: PREPROCESSING
# ==============================

num_cols = X.select_dtypes(include=[np.number]).columns
cat_cols = X.select_dtypes(include=["object"]).columns

num_imputer = SimpleImputer(strategy="median")
cat_imputer = SimpleImputer(strategy="most_frequent")

# --- Impute numerical columns ---
if not num_cols.empty:
    for col in num_cols:
        median_val = X[col].median()
        if pd.isna(median_val):
            X[col] = X[col].fillna(0)
        else:
            X[col] = X[col].fillna(median_val)

# --- Impute categorical columns ---
if not cat_cols.empty:
    for col in cat_cols:
        col_values = X[col].astype(str).values.reshape(-1, 1)
        X.loc[:, col] = pd.Series(cat_imputer.fit_transform(col_values).ravel(), index=X.index)

    for col in cat_cols:
        X[col] = LabelEncoder().fit_transform(X[col].astype(str))

# Scale numerical columns
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# Reshape for Conv1D (samples, timesteps, channels)
X = X.values.reshape(X.shape[0], X.shape[1], 1)

print("CNN input shape:", X.shape)
# Out:
# CNN input shape: (1114, 345, 1)

# %%
# ==============================
# STEP 4: TRAIN / TEST SPLIT
# ==============================

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Train:", X_train.shape)
print("Test:", X_test.shape)
# Out:
# Train: (891, 345, 1)
# Test: (223, 345, 1)

# %%
# ==============================
# STEP 5: BUILD 1D CNN MODEL
# ==============================

model = Sequential([
    Conv1D(64, kernel_size=3, activation="relu", input_shape=X.shape[1:]),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(128, kernel_size=3, activation="relu"),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Conv1D(256, kernel_size=3, activation="relu"),
    BatchNormalization(),
    MaxPooling1D(pool_size=2),

    Flatten(),
    Dense(128, activation="relu"),
    Dropout(0.5),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 343, 64)        │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 343, 64)        │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 171, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 169, 128)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 169, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 84, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 82, 256)        │        98,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 82, 256)        │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 41, 256)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 10496)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,343,616 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,469,057 (5.60 MB)
#  Trainable params: 1,468,161 (5.60 MB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# ==============================
# STEP 6: SETUP CALLBACKS
# ==============================

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=8,
        restore_best_weights=True
    ),
    ModelCheckpoint(
        "best_1d_cnn_asd_model.keras",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    )
]

print("✅ Callbacks configured!")
# Out:
# ✅ Callbacks configured!

# %%
# ==============================
# STEP 7: TRAIN MODEL
# ==============================

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.6761 - loss: 0.8239
# Epoch 1: val_accuracy improved from None to 0.44134, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 1: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 5s 77ms/step - accuracy: 0.7570 - loss: 0.5815 - val_accuracy: 0.4413 - val_loss: 1.1213
# Epoch 2/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8836 - loss: 0.2932
# Epoch 2: val_accuracy did not improve from 0.44134
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9031 - loss: 0.2496 - val_accuracy: 0.4413 - val_loss: 0.8314
# Epoch 3/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8972 - loss: 0.2255
# Epoch 3: val_accuracy did not improve from 0.44134
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - accuracy: 0.9129 - loss: 0.2060 - val_accuracy: 0.4413 - val_loss: 0.9121
# Epoch 4/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9244 - loss: 0.1729
# Epoch 4: val_accuracy improved from 0.44134 to 0.51397, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 4: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9185 - loss: 0.1812 - val_accuracy: 0.5140 - val_loss: 0.6431
# Epoch 5/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9189 - loss: 0.2012
# Epoch 5: val_accuracy did not improve from 0.51397
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9340 - loss: 0.1640 - val_accuracy: 0.4413 - val_loss: 0.7925
# Epoch 6/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9565 - loss: 0.1287
# Epoch 6: val_accuracy did not improve from 0.51397
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step - accuracy: 0.9565 - loss: 0.1221 - val_accuracy: 0.4469 - val_loss: 0.7715
# Epoch 7/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9605 - loss: 0.1133
# Epoch 7: val_accuracy did not improve from 0.51397
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9607 - loss: 0.1114 - val_accuracy: 0.4749 - val_loss: 0.6793
# Epoch 8/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9611 - loss: 0.1021
# Epoch 8: val_accuracy improved from 0.51397 to 0.53073, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 8: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9565 - loss: 0.1110 - val_accuracy: 0.5307 - val_loss: 0.6512
# Epoch 9/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9598 - loss: 0.1048
# Epoch 9: val_accuracy improved from 0.53073 to 0.55866, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 9: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9677 - loss: 0.0911 - val_accuracy: 0.5587 - val_loss: 0.6464
# Epoch 10/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9764 - loss: 0.0823
# Epoch 10: val_accuracy improved from 0.55866 to 0.87709, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 10: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step - accuracy: 0.9803 - loss: 0.0803 - val_accuracy: 0.8771 - val_loss: 0.3461
# Epoch 11/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9755 - loss: 0.0611
# Epoch 11: val_accuracy did not improve from 0.87709
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9761 - loss: 0.0593 - val_accuracy: 0.6872 - val_loss: 0.5052
# Epoch 12/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9678 - loss: 0.0922
# Epoch 12: val_accuracy did not improve from 0.87709
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 56ms/step - accuracy: 0.9761 - loss: 0.0752 - val_accuracy: 0.7095 - val_loss: 0.4331
# Epoch 13/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9894 - loss: 0.0518
# Epoch 13: val_accuracy did not improve from 0.87709
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9888 - loss: 0.0491 - val_accuracy: 0.7765 - val_loss: 0.3656
# Epoch 14/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9864 - loss: 0.0486
# Epoch 14: val_accuracy did not improve from 0.87709
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9846 - loss: 0.0553 - val_accuracy: 0.7654 - val_loss: 0.3745
# Epoch 15/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9822 - loss: 0.0695
# Epoch 15: val_accuracy did not improve from 0.87709
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9874 - loss: 0.0586 - val_accuracy: 0.8156 - val_loss: 0.3022
# Epoch 16/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9745 - loss: 0.0640
# Epoch 16: val_accuracy improved from 0.87709 to 0.96089, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 16: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - accuracy: 0.9789 - loss: 0.0628 - val_accuracy: 0.9609 - val_loss: 0.1354
# Epoch 17/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9892 - loss: 0.0759
# Epoch 17: val_accuracy improved from 0.96089 to 0.96648, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 17: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9874 - loss: 0.0604 - val_accuracy: 0.9665 - val_loss: 0.1166
# Epoch 18/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9878 - loss: 0.0496
# Epoch 18: val_accuracy improved from 0.96648 to 0.98324, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 18: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9817 - loss: 0.0624 - val_accuracy: 0.9832 - val_loss: 0.1101
# Epoch 19/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9926 - loss: 0.0336
# Epoch 19: val_accuracy did not improve from 0.98324
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9846 - loss: 0.0519 - val_accuracy: 0.7765 - val_loss: 0.3532
# Epoch 20/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9887 - loss: 0.0439
# Epoch 20: val_accuracy did not improve from 0.98324
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9902 - loss: 0.0425 - val_accuracy: 0.9832 - val_loss: 0.0786
# Epoch 21/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.9883 - loss: 0.0373
# Epoch 21: val_accuracy did not improve from 0.98324
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 66ms/step - accuracy: 0.9902 - loss: 0.0370 - val_accuracy: 0.9777 - val_loss: 0.0756
# Epoch 22/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9848 - loss: 0.0522
# Epoch 22: val_accuracy did not improve from 0.98324
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9831 - loss: 0.0561 - val_accuracy: 0.9777 - val_loss: 0.0584
# Epoch 23/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9868 - loss: 0.0501
# Epoch 23: val_accuracy did not improve from 0.98324
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 0.9888 - loss: 0.0421 - val_accuracy: 0.9777 - val_loss: 0.0798
# Epoch 24/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9952 - loss: 0.0256
# Epoch 24: val_accuracy improved from 0.98324 to 0.98883, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 24: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9902 - loss: 0.0401 - val_accuracy: 0.9888 - val_loss: 0.0555
# Epoch 25/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9885 - loss: 0.0284
# Epoch 25: val_accuracy did not improve from 0.98883
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9916 - loss: 0.0304 - val_accuracy: 0.9777 - val_loss: 0.0548
# Epoch 26/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9927 - loss: 0.0306
# Epoch 26: val_accuracy did not improve from 0.98883
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9930 - loss: 0.0310 - val_accuracy: 0.9832 - val_loss: 0.0607
# Epoch 27/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9887 - loss: 0.0400
# Epoch 27: val_accuracy did not improve from 0.98883
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - accuracy: 0.9803 - loss: 0.0527 - val_accuracy: 0.9609 - val_loss: 0.0961
# Epoch 28/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9851 - loss: 0.0528
# Epoch 28: val_accuracy did not improve from 0.98883
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 68ms/step - accuracy: 0.9874 - loss: 0.0420 - val_accuracy: 0.9665 - val_loss: 0.0669
# Epoch 29/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - accuracy: 0.9803 - loss: 0.0407
# Epoch 29: val_accuracy did not improve from 0.98883
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9789 - loss: 0.0489 - val_accuracy: 0.9888 - val_loss: 0.0465
# Epoch 30/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.9902 - loss: 0.0454
# Epoch 30: val_accuracy did not improve from 0.98883
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step - accuracy: 0.9874 - loss: 0.0515 - val_accuracy: 0.9832 - val_loss: 0.0572
# Epoch 31/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9863 - loss: 0.0450
# Epoch 31: val_accuracy did not improve from 0.98883
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9916 - loss: 0.0357 - val_accuracy: 0.9665 - val_loss: 0.0590
# Epoch 32/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9903 - loss: 0.0208
# Epoch 32: val_accuracy improved from 0.98883 to 0.99441, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 32: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.9846 - loss: 0.0298 - val_accuracy: 0.9944 - val_loss: 0.0356
# Epoch 33/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9930 - loss: 0.0268
# Epoch 33: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.9874 - loss: 0.0316 - val_accuracy: 0.9777 - val_loss: 0.0430
# Epoch 34/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9834 - loss: 0.0323
# Epoch 34: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9846 - loss: 0.0333 - val_accuracy: 0.9944 - val_loss: 0.0312
# Epoch 35/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9950 - loss: 0.0215
# Epoch 35: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9916 - loss: 0.0288 - val_accuracy: 0.9944 - val_loss: 0.0278
# Epoch 36/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9859 - loss: 0.0438
# Epoch 36: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9831 - loss: 0.0489 - val_accuracy: 0.9721 - val_loss: 0.0817
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9836 - loss: 0.0531
# Epoch 37: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9874 - loss: 0.0419 - val_accuracy: 0.9832 - val_loss: 0.0444
# Epoch 38/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9834 - loss: 0.0486
# Epoch 38: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9860 - loss: 0.0437 - val_accuracy: 0.9832 - val_loss: 0.0336
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9908 - loss: 0.0368
# Epoch 39: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - accuracy: 0.9902 - loss: 0.0340 - val_accuracy: 0.9888 - val_loss: 0.0291
# Epoch 40/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9876 - loss: 0.0403
# Epoch 40: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9902 - loss: 0.0316 - val_accuracy: 0.9832 - val_loss: 0.0375
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9937 - loss: 0.0207
# Epoch 41: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9888 - loss: 0.0310 - val_accuracy: 0.9888 - val_loss: 0.0459
# Epoch 42/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.9839 - loss: 0.0409
# Epoch 42: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9846 - loss: 0.0362 - val_accuracy: 0.9888 - val_loss: 0.0488
# Epoch 43/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9972 - loss: 0.0171
# Epoch 43: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9944 - loss: 0.0240 - val_accuracy: 0.9888 - val_loss: 0.0256
# Epoch 44/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.9938 - loss: 0.0160
# Epoch 44: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.9958 - loss: 0.0175 - val_accuracy: 0.9888 - val_loss: 0.0281
# Epoch 45/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9941 - loss: 0.0194
# Epoch 45: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step - accuracy: 0.9944 - loss: 0.0177 - val_accuracy: 0.9888 - val_loss: 0.0256
# Epoch 46/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9964 - loss: 0.0140
# Epoch 46: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - accuracy: 0.9944 - loss: 0.0189 - val_accuracy: 0.9944 - val_loss: 0.0288
# Epoch 47/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9951 - loss: 0.0176
# Epoch 47: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9958 - loss: 0.0163 - val_accuracy: 0.9888 - val_loss: 0.0234
# Epoch 48/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - accuracy: 0.9957 - loss: 0.0178
# Epoch 48: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.9944 - loss: 0.0183 - val_accuracy: 0.9888 - val_loss: 0.0183
# Epoch 49/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9948 - loss: 0.0179
# Epoch 49: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.9944 - loss: 0.0190 - val_accuracy: 0.9832 - val_loss: 0.0331
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9913 - loss: 0.0226
# Epoch 50: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step - accuracy: 0.9930 - loss: 0.0173 - val_accuracy: 0.9888 - val_loss: 0.0323
# Epoch 51/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - accuracy: 0.9989 - loss: 0.0059
# Epoch 51: val_accuracy did not improve from 0.99441
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.9972 - loss: 0.0123 - val_accuracy: 0.9832 - val_loss: 0.0520
# Epoch 52/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - accuracy: 0.9923 - loss: 0.0249
# Epoch 52: val_accuracy improved from 0.99441 to 1.00000, saving model to best_1d_cnn_asd_model.keras
#
# Epoch 52: finished saving model to best_1d_cnn_asd_model.keras
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step - accuracy: 0.9916 - loss: 0.0263 - val_accuracy: 1.0000 - val_loss: 0.0264
# Epoch 53/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9935 - loss: 0.0185
# Epoch 53: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.9930 - loss: 0.0157 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 54/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9952 - loss: 0.0141
# Epoch 54: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9944 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 0.0116
# Epoch 55/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9988 - loss: 0.0080
# Epoch 55: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step - accuracy: 0.9986 - loss: 0.0084 - val_accuracy: 0.9888 - val_loss: 0.0221
# Epoch 56/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9964 - loss: 0.0129
# Epoch 56: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 91ms/step - accuracy: 0.9958 - loss: 0.0124 - val_accuracy: 0.9888 - val_loss: 0.0306
# Epoch 57/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.9995 - loss: 0.0029
# Epoch 57: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 89ms/step - accuracy: 0.9972 - loss: 0.0074 - val_accuracy: 0.9944 - val_loss: 0.0380
# Epoch 58/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9926 - loss: 0.0271
# Epoch 58: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9930 - loss: 0.0233 - val_accuracy: 0.9832 - val_loss: 0.0324
# Epoch 59/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9961 - loss: 0.0102
# Epoch 59: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9958 - loss: 0.0103 - val_accuracy: 0.9944 - val_loss: 0.0163
# Epoch 60/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.9911 - loss: 0.0198
# Epoch 60: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 99ms/step - accuracy: 0.9944 - loss: 0.0157 - val_accuracy: 0.9944 - val_loss: 0.0164
# Epoch 61/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.9993 - loss: 0.0073
# Epoch 61: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - accuracy: 0.9958 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0089
# Epoch 62/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9998 - loss: 0.0069
# Epoch 62: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 66ms/step - accuracy: 0.9972 - loss: 0.0119 - val_accuracy: 0.9888 - val_loss: 0.0232
# Epoch 63/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.9972 - loss: 0.0071
# Epoch 63: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step - accuracy: 0.9930 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 64/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.9958 - loss: 0.0116
# Epoch 64: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step - accuracy: 0.9958 - loss: 0.0105 - val_accuracy: 0.9944 - val_loss: 0.0135
# Epoch 65/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9976 - loss: 0.0079
# Epoch 65: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9958 - loss: 0.0085 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 66/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.9940 - loss: 0.0085
# Epoch 66: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - accuracy: 0.9930 - loss: 0.0111 - val_accuracy: 0.9944 - val_loss: 0.0116
# Epoch 67/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - accuracy: 0.9909 - loss: 0.0159
# Epoch 67: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - accuracy: 0.9972 - loss: 0.0094 - val_accuracy: 0.9888 - val_loss: 0.0281
# Epoch 68/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.9967 - loss: 0.0089
# Epoch 68: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 97ms/step - accuracy: 0.9972 - loss: 0.0094 - val_accuracy: 0.9944 - val_loss: 0.0138
# Epoch 69/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9999 - loss: 0.0055
# Epoch 69: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 92ms/step - accuracy: 0.9986 - loss: 0.0058 - val_accuracy: 0.9944 - val_loss: 0.0123
# Epoch 70/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 1.0000 - loss: 0.0052
# Epoch 70: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step - accuracy: 1.0000 - loss: 0.0047 - val_accuracy: 0.9944 - val_loss: 0.0129
# Epoch 71/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.9988 - loss: 0.0041
# Epoch 71: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.9944 - val_loss: 0.0089
# Epoch 72/100
# 22/23 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 1.0000 - loss: 0.0019
# Epoch 72: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 102ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9944 - val_loss: 0.0094
# Epoch 73/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9954 - loss: 0.0112
# Epoch 73: val_accuracy did not improve from 1.00000
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.9972 - loss: 0.0087 - val_accuracy: 0.9944 - val_loss: 0.0229

# %%
# ==============================
# STEP 8: EVALUATION
# ==============================

y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob > 0.5).astype(int)

acc = accuracy_score(y_test, y_pred) * 100
roc = roc_auc_score(y_test, y_pred_prob)

print(f"Accuracy: {acc:.2f}%")
print(f"ROC-AUC: {roc:.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
# Accuracy: 98.21%
# ROC-AUC: 0.9989
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98       119
#            1       0.99      0.97      0.98       104
#
#     accuracy                           0.98       223
#    macro avg       0.98      0.98      0.98       223
# weighted avg       0.98      0.98      0.98       223

# %%
# ==============================
# STEP 9: SAVE MODEL
# ==============================

model.save("final_1d_cnn_asd_model.keras")
print("✅ Model saved as final_1d_cnn_asd_model.keras")
# Out:
# ✅ Model saved as final_1d_cnn_asd_model.keras
