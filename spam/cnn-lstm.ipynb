# %%
# ==============================
# STEP 0: INSTALL & IMPORTS
# ==============================

import warnings
warnings.filterwarnings("ignore")
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'  # Suppress TensorFlow warnings

import numpy as np
import pandas as pd
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    LSTM, Dense, Dropout, BatchNormalization
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.impute import SimpleImputer
from sklearn.metrics import classification_report, roc_auc_score, accuracy_score

# %%
# ==============================
# STEP 1: LOAD DATA
# ==============================

FILE_PATH = "ABIDEII_Composite_Phenotypic.csv"

df = pd.read_csv(FILE_PATH, encoding="latin1", engine="python")
print("Dataset shape:", df.shape)
df.head()
# Out:
# Dataset shape: (1114, 348)
#          SITE_ID  SUB_ID NDAR_GUID  DX_GROUP  PDD_DSM_IV_TR  ASD_DSM_5  \
# 0  ABIDEII-BNI_1   29006       NaN         1            NaN        NaN
# 1  ABIDEII-BNI_1   29007       NaN         1            NaN        NaN
# 2  ABIDEII-BNI_1   29008       NaN         1            NaN        NaN
# 3  ABIDEII-BNI_1   29009       NaN         1            NaN        NaN
# 4  ABIDEII-BNI_1   29010       NaN         1            NaN        NaN
#
#    AGE_AT_SCAN   SEX  HANDEDNESS_CATEGORY  HANDEDNESS_SCORES  ...  \
# 0          48.0    1                  1.0                NaN  ...
# 1          41.0    1                  1.0                NaN  ...
# 2          59.0    1                  1.0                NaN  ...
# 3          57.0    1                  1.0                NaN  ...
# 4          45.0    1                  1.0                NaN  ...
#
#    ADI_R_C3_TOTAL  ADI_R_C4_REPETITIVE_USE_OBJECTS  ADI_R_C4_HIGHER  \
# 0             NaN                              NaN              NaN
# 1             NaN                              NaN              NaN
# 2             NaN                              NaN              NaN
# 3             NaN                              NaN              NaN
# 4             NaN                              NaN              NaN
#
#   ADI_R_C4_UNUSUAL_SENSORY_INTERESTS ADI_R_C4_TOTAL  \
# 0                                NaN            NaN
# 1                                NaN            NaN
# 2                                NaN            NaN
# 3                                NaN            NaN
# 4                                NaN            NaN
#
#   ADI_R_D_AGE_PARENT_NOTICED  ADI_R_D_AGE_FIRST_SINGLE_WORDS  \
# 0                        NaN                             NaN
# 1                        NaN                             NaN
# 2                        NaN                             NaN
# 3                        NaN                             NaN
# 4                        NaN                             NaN
#
#    ADI_R_D_AGE_FIRST_PHRASES  ADI_R_D_AGE_WHEN_ABNORMALITY  \
# 0                        NaN                           NaN
# 1                        NaN                           NaN
# 2                        NaN                           NaN
# 3                        NaN                           NaN
# 4                        NaN                           NaN
#
#    ADI_R_D_INTERVIEWER_JUDGMENT
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
# [5 rows x 348 columns]

# %%
# ==============================
# STEP 2: TARGET & FEATURE SPLIT
# ==============================

TARGET = "DX_GROUP"   # 1 = ASD, 2 = Control

# Binary classification (not regression)
y = df[TARGET].map({1: 1, 2: 0})

drop_cols = ["DX_GROUP", "SUB_ID", "FILE_ID", "SITE_ID"]
X = df.drop(columns=[c for c in drop_cols if c in df.columns])

print("X shape:", X.shape)
print("y distribution:\n", y.value_counts())
# Out:
# X shape: (1114, 345)
# y distribution:
#  DX_GROUP
# 0    593
# 1    521
# Name: count, dtype: int64

# %%
# ==============================
# STEP 3: PREPROCESSING
# ==============================

num_cols = X.select_dtypes(include=[np.number]).columns
cat_cols = X.select_dtypes(include=["object"]).columns

num_imputer = SimpleImputer(strategy="median")
cat_imputer = SimpleImputer(strategy="most_frequent")

# Numerical imputation
if not num_cols.empty:
    for col in num_cols:
        median_val = X[col].median()
        if pd.isna(median_val):
            X[col] = X[col].fillna(0)
        else:
            X[col] = X[col].fillna(median_val)

# Impute categorical columns
if not cat_cols.empty:
    for col in cat_cols:
        col_values = X[col].astype(str).values.reshape(-1, 1)
        X.loc[:, col] = pd.Series(cat_imputer.fit_transform(col_values).ravel(), index=X.index)

    for col in cat_cols:
        X[col] = LabelEncoder().fit_transform(X[col])

# Scaling
scaler = StandardScaler()
X[num_cols] = scaler.fit_transform(X[num_cols])

# Reshape for LSTM (samples, timesteps, features)
X = X.values.reshape(X.shape[0], X.shape[1], 1)

print("LSTM input shape:", X.shape)
# Out:
# LSTM input shape: (1114, 345, 1)

# %%
# ==============================
# STEP 4: TRAIN / TEST SPLIT
# ==============================

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Train:", X_train.shape)
print("Test:", X_test.shape)
# Out:
# Train: (891, 345, 1)
# Test: (223, 345, 1)

# %%
# ==============================
# STEP 5: BUILD LSTM MODEL
# ==============================

model = Sequential([
    LSTM(128, return_sequences=True, input_shape=X.shape[1:]),
    BatchNormalization(),
    Dropout(0.3),

    LSTM(64),
    BatchNormalization(),
    Dropout(0.3),

    Dense(64, activation="relu"),
    Dropout(0.3),

    Dense(1, activation="sigmoid")  # Binary classification
])

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 345, 128)       │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 345, 128)       │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 345, 128)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 64)             │        49,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,961 (472.50 KB)
#  Trainable params: 120,577 (471.00 KB)
#  Non-trainable params: 384 (1.50 KB)

# %%
# ==============================
# STEP 6: SETUP CALLBACKS
# ==============================

callbacks = [
    EarlyStopping(
        monitor="val_loss",
        patience=8,
        restore_best_weights=True
    ),
    ModelCheckpoint(
        "best_lstm_asd_model.h5",
        monitor="val_accuracy",
        save_best_only=True,
        verbose=1
    )
]

print("✅ Callbacks configured!")
# Out:
# ✅ Callbacks configured!

# %%
# ==============================
# STEP 7: TRAIN MODEL
# ==============================

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=100,
    batch_size=32,
    callbacks=callbacks,
    verbose=1
)
# Out:
# Epoch 1/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.5167 - loss: 0.7457
# Epoch 1: val_accuracy improved from None to 0.59218, saving model to best_lstm_asd_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 1: finished saving model to best_lstm_asd_model.h5
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 36s 633ms/step - accuracy: 0.5183 - loss: 0.7329 - val_accuracy: 0.5922 - val_loss: 0.6903
# Epoch 2/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.4860 - loss: 0.7489
# Epoch 2: val_accuracy did not improve from 0.59218
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 483ms/step - accuracy: 0.5239 - loss: 0.7297 - val_accuracy: 0.5922 - val_loss: 0.6901
# Epoch 3/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.5081 - loss: 0.7177
# Epoch 3: val_accuracy improved from 0.59218 to 0.60894, saving model to best_lstm_asd_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Epoch 3: finished saving model to best_lstm_asd_model.h5
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 20s 464ms/step - accuracy: 0.5337 - loss: 0.7086 - val_accuracy: 0.6089 - val_loss: 0.6899
# Epoch 4/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.5394 - loss: 0.6992
# Epoch 4: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 11s 487ms/step - accuracy: 0.5197 - loss: 0.7050 - val_accuracy: 0.4413 - val_loss: 0.6893
# Epoch 5/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 504ms/step - accuracy: 0.4846 - loss: 0.7173
# Epoch 5: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 13s 559ms/step - accuracy: 0.4775 - loss: 0.7152 - val_accuracy: 0.4413 - val_loss: 0.6886
# Epoch 6/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.5075 - loss: 0.7044
# Epoch 6: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 12s 489ms/step - accuracy: 0.5183 - loss: 0.7071 - val_accuracy: 0.4413 - val_loss: 0.6888
# Epoch 7/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - accuracy: 0.5553 - loss: 0.6945
# Epoch 7: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 14s 624ms/step - accuracy: 0.5351 - loss: 0.6966 - val_accuracy: 0.4413 - val_loss: 0.6875
# Epoch 8/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.5333 - loss: 0.7030
# Epoch 8: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 439ms/step - accuracy: 0.5393 - loss: 0.6914 - val_accuracy: 0.4413 - val_loss: 0.6861
# Epoch 9/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.5277 - loss: 0.7192
# Epoch 9: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 288ms/step - accuracy: 0.5421 - loss: 0.6977 - val_accuracy: 0.4413 - val_loss: 0.6847
# Epoch 10/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.5128 - loss: 0.7228
# Epoch 10: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 267ms/step - accuracy: 0.5084 - loss: 0.7138 - val_accuracy: 0.4413 - val_loss: 0.6843
# Epoch 11/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - accuracy: 0.5381 - loss: 0.6919
# Epoch 11: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 269ms/step - accuracy: 0.5520 - loss: 0.6909 - val_accuracy: 0.4413 - val_loss: 0.6839
# Epoch 12/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.5308 - loss: 0.6894
# Epoch 12: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - accuracy: 0.5281 - loss: 0.6864 - val_accuracy: 0.4413 - val_loss: 0.6832
# Epoch 13/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - accuracy: 0.5883 - loss: 0.6665
# Epoch 13: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 270ms/step - accuracy: 0.5801 - loss: 0.6715 - val_accuracy: 0.4413 - val_loss: 0.6832
# Epoch 14/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 0.5274 - loss: 0.6794
# Epoch 14: val_accuracy did not improve from 0.60894
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step
val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 382ms/step - accuracy: 0.5576 - loss: 0.6707 - val_accuracy: 0.6145 - val_loss: 0.6455
# Epoch 36/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.5142 - loss: 0.6753
# Epoch 36: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 376ms/step - accuracy: 0.5183 - loss: 0.6798 - val_accuracy: 0.6145 - val_loss: 0.6507
# Epoch 37/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.5429 - loss: 0.6710
# Epoch 37: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 411ms/step - accuracy: 0.5337 - loss: 0.6774 - val_accuracy: 0.6145 - val_loss: 0.6459
# Epoch 38/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.5454 - loss: 0.6901
# Epoch 38: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 319ms/step - accuracy: 0.5253 - loss: 0.6870 - val_accuracy: 0.6145 - val_loss: 0.6420
# Epoch 39/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.5553 - loss: 0.6722
# Epoch 39: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 336ms/step - accuracy: 0.5506 - loss: 0.6692 - val_accuracy: 0.6145 - val_loss: 0.6443
# Epoch 40/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step - accuracy: 0.5412 - loss: 0.6838
# Epoch 40: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 329ms/step - accuracy: 0.5154 - loss: 0.6886 - val_accuracy: 0.6145 - val_loss: 0.6470
# Epoch 41/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.5367 - loss: 0.6790
# Epoch 41: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - accuracy: 0.5506 - loss: 0.6785 - val_accuracy: 0.6145 - val_loss: 0.6408
# Epoch 42/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.5430 - loss: 0.6726
# Epoch 42: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 386ms/step - accuracy: 0.5449 - loss: 0.6765 - val_accuracy: 0.6145 - val_loss: 0.6404
# Epoch 43/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step - accuracy: 0.5456 - loss: 0.6675
# Epoch 43: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 8s 343ms/step - accuracy: 0.5281 - loss: 0.6736 - val_accuracy: 0.6145 - val_loss: 0.6401
# Epoch 44/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - accuracy: 0.5563 - loss: 0.6660
# Epoch 44: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 302ms/step - accuracy: 0.5379 - loss: 0.6744 - val_accuracy: 0.6145 - val_loss: 0.6429
# Epoch 45/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.5422 - loss: 0.6956
# Epoch 45: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 9s 413ms/step - accuracy: 0.5281 - loss: 0.6858 - val_accuracy: 0.6145 - val_loss: 0.6434
# Epoch 46/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.5418 - loss: 0.6699
# Epoch 46: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 313ms/step - accuracy: 0.5169 - loss: 0.6849 - val_accuracy: 0.6145 - val_loss: 0.6452
# Epoch 47/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step - accuracy: 0.5011 - loss: 0.6802
# Epoch 47: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.5154 - loss: 0.6850 - val_accuracy: 0.6145 - val_loss: 0.6417
# Epoch 48/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.5374 - loss: 0.6733
# Epoch 48: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.5407 - loss: 0.6763 - val_accuracy: 0.6145 - val_loss: 0.6419
# Epoch 49/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.5728 - loss: 0.6572
# Epoch 49: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 239ms/step - accuracy: 0.5506 - loss: 0.6697 - val_accuracy: 0.6145 - val_loss: 0.6404
# Epoch 50/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step - accuracy: 0.5405 - loss: 0.6825
# Epoch 50: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 6s 255ms/step - accuracy: 0.5407 - loss: 0.6780 - val_accuracy: 0.6145 - val_loss: 0.6428
# Epoch 51/100
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step - accuracy: 0.5294 - loss: 0.6866
# Epoch 51: val_accuracy did not improve from 0.61453
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 7s 294ms/step - accuracy: 0.5407 - loss: 0.6779 - val_accuracy: 0.6145 - val_loss: 0.6415

# %%
# ==============================
# STEP 8: EVALUATION
# ==============================

y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob > 0.5).astype(int)

acc = accuracy_score(y_test, y_pred) * 100
roc = roc_auc_score(y_test, y_pred_prob)

print(f"Accuracy: {acc:.2f}%")
print(f"ROC-AUC: {roc:.4f}")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step
# Accuracy: 56.50%
# ROC-AUC: 0.5302
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.55      1.00      0.71       119
#            1       1.00      0.07      0.13       104
#
#     accuracy                           0.57       223
#    macro avg       0.78      0.53      0.42       223
# weighted avg       0.76      0.57      0.44       223

# %%
# ==============================
# STEP 9: SAVE MODEL
# ==============================

model.save("final_lstm_asd_model.keras")
print("✅ LSTM model saved as final_lstm_asd_model.keras")
# Out:
# ✅ LSTM model saved as final_lstm_asd_model.keras
